# %% [markdown]
# # **PANDAS**

# %% [markdown]
# # LESSON 1: *Creating, Reading and Writing*

# %%
import pandas as pd

# %% [markdown]
# ### Creating data

# %%
pd.DataFrame({'Yes':[50,21],'No':[131,2]})
# Out:
#    Yes   No
# 0   50  131
# 1   21    2

# %%
pd.DataFrame({'Bob':['I liked it.','It was awful.'],'Sue':['pretty good.','Bland.']})
# Out:
#              Bob           Sue
# 0    I liked it.  pretty good.
# 1  It was awful.        Bland.

# %%
pd.DataFrame({'Bob':['I liked it.','It was awful.'],
              'Sue':['Pretty good.','Bland']},
             index=['Product A','Product B'])
# Out:
#                      Bob           Sue
# Product A    I liked it.  Pretty good.
# Product B  It was awful.         Bland

# %% [markdown]
# ### Series

# %%
pd.Series([1,2,3,4,5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
pd.Series([30,35,40],index=['2015 Sales','2016 Sales','2017 Sales'],name='Product A')
# Out:
# 2015 Sales    30
# 2016 Sales    35
# 2017 Sales    40
# Name: Product A, dtype: int64

# %% [markdown]
# ### Reading data files

# %%
wine_reviews=pd.read_csv(r"C:\Users\Administrator\Documents\Downloads\archive (17)\winemag-data-130k-v2.csv")

# %%
wine_reviews.shape
# Out:
# (129971, 14)

# %%
wine_reviews.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %% [markdown]
# # Exercise

# %%
fruits=pd.DataFrame({'Apples':[30],'Bananas':[21]})
fruits
# Out:
#    Apples  Bananas
# 0      30       21

# %%
fruit_sales=pd.DataFrame({'Apples':[35,41],'Bananas':[21,34]},
                         index=['2017 Sales','2018 Sales'])
fruit_sales
# Out:
#             Apples  Bananas
# 2017 Sales      35       21
# 2018 Sales      41       34

# %% [markdown]
# ### Creating a variable ingridients with series with a Series that looks like

# %%
ingredients=pd.Series(['4 cups','1 cup','2 large','1 can'],index=['Flour','Milk','Eggs','Spam'],name = 'Dinner')
ingredients
# Out:
# Flour     4 cups
# Milk       1 cup
# Eggs     2 large
# Spam       1 can
# Name: Dinner, dtype: object

# %% [markdown]
# ### Reading data

# %%
reviews=pd.read_csv(r"C:\Users\Administrator\Documents\Downloads\archive (17)\winemag-data_first150k.csv",index_col=0)
reviews
# Out:
#        country                                        description  \
# 0           US  This tremendous 100% varietal wine hails from ...
# 1        Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           US  Mac Watson honors the memory of a wine once ma...
# 3           US  This spent 20 months in 30% new French oak, an...
# 4       France  This is the top wine from La Bégude, named aft...
# ...        ...                                                ...
# 150925   Italy  Many people feel Fiano represents southern Ita...
# 150926  France  Offers an intriguing nose with ginger, lime an...
# 150927   Italy  This classic example comes from a cru vineyard...
# 150928  France  A perfect salmon shade, with scents of peaches...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                                  designation  points  price  \
# 0                          Martha's Vineyard      96  235.0
# ...

# %%
animals=pd.DataFrame({'Cows':[12,20],'Goats':[22,19]},index=['Yeat 1','Year 2'])
animals
# Out:
#         Cows  Goats
# Yeat 1    12     22
# Year 2    20     19

# %%
animals.to_csv('cows_and_goats.csv')

# %% [markdown]
# ## LESSON 2: *Indexing,Selecting & Assigning*

# %%
wine_reviews
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
wine_reviews.country
# Out:
# 0            Italy
# 1         Portugal
# 2               US
# 3               US
# 4               US
#             ...
# 129966     Germany
# 129967          US
# 129968      France
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
wine_reviews['country']
# Out:
# 0            Italy
# 1         Portugal
# 2               US
# 3               US
# 4               US
#             ...
# 129966     Germany
# 129967          US
# 129968      France
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
wine_reviews['country'][0]
# Out:
# 'Italy'

# %% [markdown]
# ### Indexing in pandas

# %% [markdown]
# #### Index-based selection

# %%
wine_reviews.iloc[0] # To select the first row of data in a DataFram , we may use the following
# Out:
# Unnamed: 0                                                               0
# country                                                              Italy
# description              Aromas include tropical fruit, broom, brimston...
# designation                                                   Vulkà Bianco
# points                                                                  87
# price                                                                  NaN
# province                                                 Sicily & Sardinia
# region_1                                                              Etna
# region_2                                                               NaN
# taster_name                                                  Kerin O’Keefe
# taster_twitter_handle                                         @kerinokeefe
# title                                    Nicosia 2013 Vulkà Bianco  (Etna)
# ...

# %%
# to get a column with iloc
wine_reviews.iloc[:,1]
# Out:
# 0            Italy
# 1         Portugal
# 2               US
# 3               US
# 4               US
#             ...
# 129966     Germany
# 129967          US
# 129968      France
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
# To get just the first 3 columns
wine_reviews.iloc[:3,1]
# Out:
# 0       Italy
# 1    Portugal
# 2          US
# Name: country, dtype: object

# %%
# To get the second and third columns
wine_reviews.iloc[2:3,1]
# Out:
# 2    US
# Name: country, dtype: object

# %%
# To pass a list
wine_reviews.iloc[[1,2,3,],1]
# Out:
# 1    Portugal
# 2          US
# 3          US
# Name: country, dtype: object

# %%
wine_reviews.iloc[-5:]
# Out:
#         Unnamed: 0  country  \
# 129966      129966  Germany
# 129967      129967       US
# 129968      129968   France
# 129969      129969   France
# 129970      129970   France
#
#                                               description  \
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# 129969  A dry style of Pinot Gris, this is crisp with ...
# 129970  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price province  \
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese      90   28.0    Mosel
# 129967                                     NaN      90   75.0   Oregon
# 129968                                   Kritt      90   30.0   Alsace
# 129969                                     NaN      90   32.0   Alsace
# 129970           Lieu-dit Harth Cuvée Caroline      90   21.0   Alsace
#
# ...

# %% [markdown]
# #### Label-based selection

# %%
wine_reviews.loc[0,'country']
# Out:
# 'Italy'

# %%
wine_reviews.loc[:,['taster_name','taster_twitter_handle','points']]
# Out:
#                taster_name taster_twitter_handle  points
# 0            Kerin O’Keefe          @kerinokeefe      87
# 1               Roger Voss            @vossroger      87
# 2             Paul Gregutt           @paulgwine       87
# 3       Alexander Peartree                   NaN      87
# 4             Paul Gregutt           @paulgwine       87
# ...                    ...                   ...     ...
# 129966  Anna Lee C. Iijima                   NaN      90
# 129967        Paul Gregutt           @paulgwine       90
# 129968          Roger Voss            @vossroger      90
# 129969          Roger Voss            @vossroger      90
# 129970          Roger Voss            @vossroger      90
#
# [129971 rows x 3 columns]

# %% [markdown]
# ### Manipulating the index

# %%
wine_reviews.set_index('title')
# Out:
#                                                     Unnamed: 0   country  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                            0     Italy
# Quinta dos Avidagos 2011 Avidagos Red (Douro)                1  Portugal
# Rainstorm 2013 Pinot Gris (Willamette Valley)                2        US
# St. Julian 2013 Reserve Late Harvest Riesling (...           3        US
# Sweet Cheeks 2012 Vintner's Reserve Wild Child ...           4        US
# ...                                                        ...       ...
# Dr. H. Thanisch (Erben Müller-Burggraef) 2013 B...      129966   Germany
# Citation 2004 Pinot Noir (Oregon)                       129967        US
# Domaine Gresser 2013 Kritt Gewurztraminer (Alsace)      129968    France
# Domaine Marcel Deiss 2012 Pinot Gris (Alsace)           129969    France
# Domaine Schoffit 2012 Lieu-dit Harth Cuvée Caro...      129970    France
#
# ...

# %% [markdown]
# ### Conditional selection

# %%
wine_reviews.country == 'Italy'
# Out:
# 0          True
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 129966    False
# 129967    False
# 129968    False
# 129969    False
# 129970    False
# Name: country, Length: 129971, dtype: bool

# %% [markdown]
# #### Conditional selection

# %%
wine_reviews.loc[wine_reviews.country == 'Italy']
# Out:
#         Unnamed: 0 country                                        description  \
# 0                0   Italy  Aromas include tropical fruit, broom, brimston...
# 6                6   Italy  Here's a bright, informal red that opens with ...
# 13              13   Italy  This is dominated by oak and oak-driven aromas...
# 22              22   Italy  Delicate aromas recall white flower and citrus...
# 24              24   Italy  Aromas of prune, blackcurrant, toast and oak c...
# ...            ...     ...                                                ...
# 129929      129929   Italy  This luminous sparkler has a sweet, fruit-forw...
# 129943      129943   Italy  A blend of Nero d'Avola and Syrah, this convey...
# 129947      129947   Italy  A blend of 65% Cabernet Sauvignon, 30% Merlot ...
# 129961      129961   Italy  Intense aromas of wild cherry, baking spice, t...
# 129962      129962   Italy  Blackberry, cassis, grilled herb and toasted a...
#
# ...

# %%
wine_reviews.loc[(wine_reviews.country == 'Italy') & (wine_reviews.points >= 90)]
# Out:
#         Unnamed: 0 country                                        description  \
# 120            120   Italy  Slightly backward, particularly given the vint...
# 130            130   Italy  At the first it was quite muted and subdued, b...
# 133            133   Italy  Einaudi's wines have been improving lately, an...
# 135            135   Italy  The color is just beginning to show signs of b...
# 140            140   Italy  A big, fat, luscious wine with plenty of toast...
# ...            ...     ...                                                ...
# 129929      129929   Italy  This luminous sparkler has a sweet, fruit-forw...
# 129943      129943   Italy  A blend of Nero d'Avola and Syrah, this convey...
# 129947      129947   Italy  A blend of 65% Cabernet Sauvignon, 30% Merlot ...
# 129961      129961   Italy  Intense aromas of wild cherry, baking spice, t...
# 129962      129962   Italy  Blackberry, cassis, grilled herb and toasted a...
#
# ...

# %%
wine_reviews.loc[(wine_reviews.country == 'Italy') | (wine_reviews.points >= 90)]
# Out:
#         Unnamed: 0  country  \
# 0                0    Italy
# 6                6    Italy
# 13              13    Italy
# 22              22    Italy
# 24              24    Italy
# ...            ...      ...
# 129966      129966  Germany
# 129967      129967       US
# 129968      129968   France
# 129969      129969   France
# 129970      129970   France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 6       Here's a bright, informal red that opens with ...
# 13      This is dominated by oak and oak-driven aromas...
# 22      Delicate aromas recall white flower and citrus...
# 24      Aromas of prune, blackcurrant, toast and oak c...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
wine_reviews.loc[wine_reviews.country.isin(['Italy','France'])] # isin lets you select data whose value 'is in' a list of values
# Out:
#         Unnamed: 0 country                                        description  \
# 0                0   Italy  Aromas include tropical fruit, broom, brimston...
# 6                6   Italy  Here's a bright, informal red that opens with ...
# 7                7  France  This dry and restrained wine offers spice in p...
# 9                9  France  This has great depth of flavor with its fresh ...
# 11              11  France  This is a dry wine, very spicy, with a tight, ...
# ...            ...     ...                                                ...
# 129964      129964  France  Initially quite muted, this wine slowly develo...
# 129965      129965  France  While it's rich, this beautiful dry wine also ...
# 129968      129968  France  Well-drained gravel soil gives this wine its c...
# 129969      129969  France  A dry style of Pinot Gris, this is crisp with ...
# 129970      129970  France  Big, rich and off-dry, this is powered by inte...
#
# ...

# %%
wine_reviews.loc[wine_reviews.price.notnull()]
# Out:
#         Unnamed: 0   country  \
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# 5                5     Spain
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# 5       Blackberry and raspberry aromas show a typical...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %% [markdown]
# ### Assigning Data

# %%
wine_reviews['critic'] = 'everyone'
wine_reviews['critic']
# Out:
# 0         everyone
# 1         everyone
# 2         everyone
# 3         everyone
# 4         everyone
#             ...
# 129966    everyone
# 129967    everyone
# 129968    everyone
# 129969    everyone
# 129970    everyone
# Name: critic, Length: 129971, dtype: object

# %%
wine_reviews['index_backwards'] = range(len(wine_reviews) ,0,-1)
wine_reviews['index_backwards']
# Out:
# 0         129971
# 1         129970
# 2         129969
# 3         129968
# 4         129967
#            ...
# 129966         5
# 129967         4
# 129968         3
# 129969         2
# 129970         1
# Name: index_backwards, Length: 129971, dtype: int64

# %% [markdown]
# # Exercise

# %%
reviews=pd.read_csv(r"C:\Users\Administrator\Documents\Downloads\archive (17)\winemag-data-130k-v2.csv")
pd.set_option('display.max_rows',5)

# %%
reviews.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %% [markdown]
# ### *1) Select the description column from reviews and assign the result to the varibale dess.*

# %%
desc=reviews['description']
desc
# Out:
# 0         Aromas include tropical fruit, broom, brimston...
# 1         This is ripe and fruity, a wine that is smooth...
#                                 ...
# 129969    A dry style of Pinot Gris, this is crisp with ...
# 129970    Big, rich and off-dry, this is powered by inte...
# Name: description, Length: 129971, dtype: object

# %%
# Alternatively
desc=reviews.description
desc
# Out:
# 0         Aromas include tropical fruit, broom, brimston...
# 1         This is ripe and fruity, a wine that is smooth...
#                                 ...
# 129969    A dry style of Pinot Gris, this is crisp with ...
# 129970    Big, rich and off-dry, this is powered by inte...
# Name: description, Length: 129971, dtype: object

# %% [markdown]
# ### *2) Select the first value from the description column of the reviews, assigning it to varibale first_description*

# %%
first_description=reviews.loc[0,'description']
first_description
# Out:
# "Aromas include tropical fruit, broom, brimstone and dried herb. The palate isn't overly expressive, offering unripened apple, citrus and dried sage alongside brisk acidity."

# %%
# Alternatively 
first_description=reviews.description.iloc[0]
first_description
# Out:
# "Aromas include tropical fruit, broom, brimstone and dried herb. The palate isn't overly expressive, offering unripened apple, citrus and dried sage alongside brisk acidity."

# %% [markdown]
# ### *3) Select the first row of data ( the first record) from reviews,assigning it to the varibale first_row.*

# %%
first_row=reviews.iloc[0]
first_row
# Out:
# Unnamed: 0              0
# country             Italy
#                  ...
# variety       White Blend
# winery            Nicosia
# Name: 0, Length: 14, dtype: object

# %% [markdown]
# ### *4)Select the first 10 values from the description column in reviews assigning the result to varbiable first_descriptions.*

# %%
first_description=reviews.description.iloc[0:10]
first_description
# Out:
# 0    Aromas include tropical fruit, broom, brimston...
# 1    This is ripe and fruity, a wine that is smooth...
#                            ...
# 8    Savory dried thyme notes accent sunnier flavor...
# 9    This has great depth of flavor with its fresh ...
# Name: description, Length: 10, dtype: object

# %%
# Alternatively
first_description=reviews.description.iloc[:10]
first_description
# Out:
# 0    Aromas include tropical fruit, broom, brimston...
# 1    This is ripe and fruity, a wine that is smooth...
#                            ...
# 8    Savory dried thyme notes accent sunnier flavor...
# 9    This has great depth of flavor with its fresh ...
# Name: description, Length: 10, dtype: object

# %% [markdown]
# ### *5) Select the records with index labels 1,2,3,5 and 8, assigning the result to the varible sample_reviews*

# %%
indices = [1,2,3,5,8]
sample_reviews=reviews.iloc[indices]
sample_reviews
# Out:
#    Unnamed: 0   country                                        description  \
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 5           5     Spain  Blackberry and raspberry aromas show a typical...
# 8           8   Germany  Savory dried thyme notes accent sunnier flavor...
#
#             designation  points  price        province             region_1  \
# 1              Avidagos      87   15.0           Douro                  NaN
# 2                   NaN      87   14.0          Oregon    Willamette Valley
# 3  Reserve Late Harvest      87   13.0        Michigan  Lake Michigan Shore
# 5          Ars In Vitro      87   15.0  Northern Spain              Navarra
# 8                 Shine      87   12.0     Rheinhessen                  NaN
#
# ...

# %% [markdown]
# ### *6) Create a variable df containing the country ,province,region_1 and region_2 columns of the records with the index labels 0,1,10 and 100.*

# %%
cols=['country','province','region_1','region_2']
indices=[0,1,10,100]
df=reviews.loc[indices,cols]
df
# Out:
#       country           province      region_1      region_2
# 0       Italy  Sicily & Sardinia          Etna           NaN
# 1    Portugal              Douro           NaN           NaN
# 10         US         California   Napa Valley          Napa
# 100        US           New York  Finger Lakes  Finger Lakes

# %% [markdown]
# ### *7) Create a varibale df containing the country and variet y columns of the first 100 records*

# %%
# using label-based selection
cols=['country','variety']
df=reviews.loc[:99,cols]
df
# Out:
#      country                   variety
# 0      Italy               White Blend
# 1   Portugal            Portuguese Red
# ..       ...                       ...
# 98     Italy                Sangiovese
# 99        US  Bordeaux-style Red Blend
#
# [100 rows x 2 columns]

# %%
# using the index-based selection
cols_idx=[0,11]
df=reviews.iloc[:100,cols_idx]
df
# Out:
#     Unnamed: 0                                              title
# 0            0                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            1      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# ..         ...                                                ...
# 98          98  Serpaia di Endrizzi 2010 Dono Riserva  (Morell...
# 99          99  Soquel Vineyards 2013 Intreccio Library Select...
#
# [100 rows x 2 columns]

# %% [markdown]
# ### *8) Create a DataFrame italian_wines conatinign reviews of wines of wines made in Italy*

# %%
italian_wines=reviews.loc[reviews.country == 'Italy']
italian_wines
# Out:
#         Unnamed: 0 country                                        description  \
# 0                0   Italy  Aromas include tropical fruit, broom, brimston...
# 6                6   Italy  Here's a bright, informal red that opens with ...
# ...            ...     ...                                                ...
# 129961      129961   Italy  Intense aromas of wild cherry, baking spice, t...
# 129962      129962   Italy  Blackberry, cassis, grilled herb and toasted a...
#
#                       designation  points  price           province  region_1  \
# 0                    Vulkà Bianco      87    NaN  Sicily & Sardinia      Etna
# 6                         Belsito      87   16.0  Sicily & Sardinia  Vittoria
# ...                           ...     ...    ...                ...       ...
# 129961                        NaN      90   30.0  Sicily & Sardinia   Sicilia
# 129962  Sàgana Tenuta San Giacomo      90   40.0  Sicily & Sardinia   Sicilia
#
# ...

# %%
# Alternatively
italian_wines=reviews[reviews.country == 'Italy']
italian_wines
# Out:
#         Unnamed: 0 country                                        description  \
# 0                0   Italy  Aromas include tropical fruit, broom, brimston...
# 6                6   Italy  Here's a bright, informal red that opens with ...
# ...            ...     ...                                                ...
# 129961      129961   Italy  Intense aromas of wild cherry, baking spice, t...
# 129962      129962   Italy  Blackberry, cassis, grilled herb and toasted a...
#
#                       designation  points  price           province  region_1  \
# 0                    Vulkà Bianco      87    NaN  Sicily & Sardinia      Etna
# 6                         Belsito      87   16.0  Sicily & Sardinia  Vittoria
# ...                           ...     ...    ...                ...       ...
# 129961                        NaN      90   30.0  Sicily & Sardinia   Sicilia
# 129962  Sàgana Tenuta San Giacomo      90   40.0  Sicily & Sardinia   Sicilia
#
# ...

# %% [markdown]
# ### *9)Create a DataFrame top_oceania_wines containing all reviews with at least 95 points (out of 100) for wines from Australia or new zealand*

# %%
top_oceania_wines=reviews.loc[reviews.country.isin(['Austalia','New Zealand'])& (reviews.points >=95)]
top_oceania_wines
# Out:
#         Unnamed: 0      country  \
# 91851        91851  New Zealand
# 122507      122507  New Zealand
#
#                                               description  \
# 91851   This full-bodied, richly tannic wine delivers....
# 122507  This blend of Cabernet Sauvignon (62.5%), Merl...
#
#                                   designation  points  price     province  \
# 91851                                  Homage      95  100.0  Hawke's Bay
# 122507  SQM Gimblett Gravels Cabernets/Merlot      95   79.0  Hawke's Bay
#
#        region_1 region_2     taster_name taster_twitter_handle  \
# 91851       NaN      NaN  Joe Czerwinski                @JoeCz
# 122507      NaN      NaN  Joe Czerwinski                @JoeCz
#
#                                                     title  \
# 91851        Trinity Hill 2013 Homage Syrah (Hawke's Bay)
# 122507  Squawking Magpie 2014 SQM Gimblett Gravels Cab...
#
#                          variety            winery
# ...

# %% [markdown]
# ## LESSON 3: *Summary Functions and Maps*

# %%
reviews
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# ...            ...       ...
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# ...                                                   ...
# 129969  A dry style of Pinot Gris, this is crisp with ...
# 129970  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# ...

# %% [markdown]
# ## Summary functions

# %%
reviews.points.describe()
# Out:
# count    129971.000000
# mean         88.447138
#              ...
# 75%          91.000000
# max         100.000000
# Name: points, Length: 8, dtype: float64

# %%
reviews.taster_name.describe()
# Out:
# count         103727
# unique            19
# top       Roger Voss
# freq           25514
# Name: taster_name, dtype: object

# %%
reviews.points.mean() # to get the mean we use 'mean()' function
# Out:
# 88.44713820775404

# %%
reviews.taster_name.unique() # to get unique values we use 'unique()' function
# Out:
# array(['Kerin O’Keefe', 'Roger Voss', 'Paul Gregutt',
#        'Alexander Peartree', 'Michael Schachner', 'Anna Lee C. Iijima',
#        'Virginie Boone', 'Matt Kettmann', nan, 'Sean P. Sullivan',
#        'Jim Gordon', 'Joe Czerwinski', 'Anne Krebiehl\xa0MW',
#        'Lauren Buzzeo', 'Mike DeSimone', 'Jeff Jenssen',
#        'Susan Kostrzewa', 'Carrie Dykes', 'Fiona Adams',
#        'Christina Pickard'], dtype=object)

# %%
# To see a list of unique values and how oftern they occuer in a dataset
reviews.taster_name.value_counts()
# Out:
# taster_name
# Roger Voss           25514
# Michael Schachner    15134
#                      ...
# Fiona Adams             27
# Christina Pickard        6
# Name: count, Length: 19, dtype: int64

# %% [markdown]
# ## Maps

# %%
# Eg we wanna remean the scores the wines received to 0
review_points_mean=reviews.points.mean()
reviews.points.map(lambda p:p - review_points_mean)
# Out:
# 0        -1.447138
# 1        -1.447138
#             ...
# 129969    1.552862
# 129970    1.552862
# Name: points, Length: 129971, dtype: float64

# %%
# 'apply()' method is an equivalent if we want to transform a whole daatframe by aclling a custom method
def remean_points(row):
    row.points=row.points-review_points_mean
    return row
reviews.apply(remean_points,axis='columns')
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# ...            ...       ...
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# ...                                                   ...
# 129969  A dry style of Pinot Gris, this is crisp with ...
# 129970  Big, rich and off-dry, this is powered by inte...
#
#                           designation    points  price           province  \
# 0                        Vulkà Bianco -1.447138    NaN  Sicily & Sardinia
# 1                            Avidagos -1.447138   15.0              Douro
# ...                               ...       ...    ...                ...
# 129969                            NaN  1.552862   32.0             Alsace
# ...

# %%
reviews.head(1)
# Out:
#    Unnamed: 0 country                                        description  \
# 0           0   Italy  Aromas include tropical fruit, broom, brimston...
#
#     designation  points  price           province region_1 region_2  \
# 0  Vulkà Bianco      87    NaN  Sicily & Sardinia     Etna      NaN
#
#      taster_name taster_twitter_handle                              title  \
# 0  Kerin O’Keefe          @kerinokeefe  Nicosia 2013 Vulkà Bianco  (Etna)
#
#        variety   winery
# 0  White Blend  Nicosia

# %%
# Faster way of remeaning our points column
review_points_mean=reviews.points.mean()
reviews.points-review_points_mean
# Out:
# 0        -1.447138
# 1        -1.447138
#             ...
# 129969    1.552862
# 129970    1.552862
# Name: points, Length: 129971, dtype: float64

# %%
reviews.country + " - " + reviews.region_1
# Out:
# 0            Italy - Etna
# 1                     NaN
#                ...
# 129969    France - Alsace
# 129970    France - Alsace
# Length: 129971, dtype: object

# %% [markdown]
# # Exercise

# %% [markdown]
# ### *1) What is the median of the points column in the reviews DataFrame?*

# %%
median_points=reviews.points.median()

# %% [markdown]
# ### *2) What countries are represented in the dataset?*

# %%
countries=reviews.country.unique()
countries
# Out:
# array(['Italy', 'Portugal', 'US', 'Spain', 'France', 'Germany',
#        'Argentina', 'Chile', 'Australia', 'Austria', 'South Africa',
#        'New Zealand', 'Israel', 'Hungary', 'Greece', 'Romania', 'Mexico',
#        'Canada', nan, 'Turkey', 'Czech Republic', 'Slovenia',
#        'Luxembourg', 'Croatia', 'Georgia', 'Uruguay', 'England',
#        'Lebanon', 'Serbia', 'Brazil', 'Moldova', 'Morocco', 'Peru',
#        'India', 'Bulgaria', 'Cyprus', 'Armenia', 'Switzerland',
#        'Bosnia and Herzegovina', 'Ukraine', 'Slovakia', 'Macedonia',
#        'China', 'Egypt'], dtype=object)

# %% [markdown]
# ### *3) How often does each country appear in the dataset?*

# %%
reviews_per_country=reviews.country.value_counts()
reviews_per_country
# Out:
# country
# US        54504
# France    22093
#           ...
# China         1
# Egypt         1
# Name: count, Length: 43, dtype: int64

# %% [markdown]
# ### *4) Create variable centered_price containing a version of the price column with the mean price subtracted.*

# %%
review_price_mean=reviews.price.mean()
centered_price=reviews.price.map(lambda p:p - review_price_mean)
centered_price
# Out:
# 0               NaN
# 1        -20.363389
#             ...
# 129969    -3.363389
# 129970   -14.363389
# Name: price, Length: 129971, dtype: float64

# %%
# Alternatively
centered_price = reviews.price - reviews.price.mean()
centered_price
# Out:
# 0               NaN
# 1        -20.363389
#             ...
# 129969    -3.363389
# 129970   -14.363389
# Name: price, Length: 129971, dtype: float64

# %% [markdown]
# ### *5) I'm in economical wine buyer.Which wine is the "best bargain"? Create a variable bargain_wine with the title of the wine with the highest points-to-price ratio in the dataset*

# %%
bargain_idx = (reviews.points/reviews.price).idxmax()
bargain_wine=reviews.loc[bargain_idx,'title']
bargain_wine
# Out:
# 'Bandit NV Merlot (California)'

# %% [markdown]
# ###  *6) There are only so many words you can use when describing a bottle of wine.Is wine more likely to be "tropical' or 'fruity' ? Create a series descriptor_counts counting how many times each of these two words appears in the description column in the dataset.*

# %%
n_trop=reviews.description.map(lambda desc: 'tropical' in desc).sum()
n_fruity=reviews.description.map(lambda desc:'fruity' in desc).sum()
descriptor_counts = pd.Series([n_trop,n_fruity],index=['tropical','fruity'])
descriptor_counts
# Out:
# tropical    3607
# fruity      9090
# dtype: int64

# %% [markdown]
# ### *7) Create a series star_ratings with the number of stars corresponding to each review in the dataset*

# %%
def stars(row):
    if row.country == 'Canada':
        return 3
    elif row.points >= 95:
        return 3
    elif row.points >= 85:
        return 2
    else:
        return 1
star_ratings = reviews.apply(stars,axis ='columns')

# %% [markdown]
# ## LESSON 4: *Grouping and sorting*

# %% [markdown]
# ### Groupwise analysis

# %%
reviews.groupby('points').points.count()
# Out:
# points
# 80     397
# 81     692
#       ...
# 99      33
# 100     19
# Name: points, Length: 21, dtype: int64

# %%
# To et the cheapest wine in each point value category, we can do the following
reviews.groupby('points').price.min()
# Out:
# points
# 80      5.0
# 81      5.0
#        ...
# 99     44.0
# 100    80.0
# Name: price, Length: 21, dtype: float64

# %%
# Selecting the name of the first wine reviewed from each winery in the dataset
reviews.groupby('winery').apply(lambda df: df.title.iloc[0])
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_21152\1423514830.py:2: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   reviews.groupby('winery').apply(lambda df: df.title.iloc[0])
# winery
# 1+1=3                          1+1=3 NV Rosé Sparkling (Cava)
# 10 Knots                 10 Knots 2010 Viognier (Paso Robles)
#                                   ...
# àMaurice    àMaurice 2013 Fred Estate Syrah (Walla Walla V...
# Štoka                         Štoka 2009 Izbrani Teran (Kras)
# Length: 16757, dtype: object

# %%
# To pick out the best wine by country and province
reviews.groupby(['country','province']).apply(lambda df:df.loc[df.points.idxmax()])
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_21152\3884639395.py:2: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   reviews.groupby(['country','province']).apply(lambda df:df.loc[df.points.idxmax()])
#                             Unnamed: 0    country  \
# country   province
# Argentina Mendoza Province       82754  Argentina
#           Other                  78303  Argentina
# ...                                ...        ...
# Uruguay   San Jose               39898    Uruguay
#           Uruguay                39361    Uruguay
#
#                                                                   description  \
# country   province
# ...

# %%
# 'agg()' lets us run a bunch of different functions on your DataFrame simultaneously
reviews.groupby(['country']).price.agg([len,min,max])
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_21152\2253943621.py:2: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   reviews.groupby(['country']).price.agg([len,min,max])
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_21152\2253943621.py:2: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   reviews.groupby(['country']).price.agg([len,min,max])
#             len   min    max
# country
# Argentina  3800   4.0  230.0
# Armenia       2  14.0   15.0
# ...         ...   ...    ...
# Ukraine      14   6.0   13.0
# Uruguay     109  10.0  130.0
#
# [43 rows x 3 columns]

# %% [markdown]
# ## Multi-Indexes

# %%
# A multi-index differs from other index in that it has multiple levels
countries_reviewed=reviews.groupby(['country','province']).description.agg([len])
countries_reviewed
# Out:
#                              len
# country   province
# Argentina Mendoza Province  3264
#           Other              536
# ...                          ...
# Uruguay   San Jose             3
#           Uruguay             24
#
# [425 rows x 1 columns]

# %%
mi =countries_reviewed.index
type(mi)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %%
countries_reviewed.reset_index()
# Out:
#        country          province   len
# 0    Argentina  Mendoza Province  3264
# 1    Argentina             Other   536
# ..         ...               ...   ...
# 423    Uruguay          San Jose     3
# 424    Uruguay           Uruguay    24
#
# [425 rows x 3 columns]

# %% [markdown]
# ## Sorting

# %%
# To get data in the order we want it in we can sort it ourselves
countries_reviewed = countries_reviewed.reset_index()
countries_reviewed.sort_values(by = 'len')
# Out:
#     country               province    len
# 179  Greece  Muscat of Kefallonian      1
# 192  Greece          Sterea Ellada      1
# ..      ...                    ...    ...
# 415      US             Washington   8639
# 392      US             California  36247
#
# [425 rows x 3 columns]

# %%
# To get in descending order
countries_reviewed.sort_values(by = 'len',ascending=False)
# Out:
#     country    province    len
# 392      US  California  36247
# 415      US  Washington   8639
# ..      ...         ...    ...
# 63    Chile     Coelemu      1
# 149  Greece      Beotia      1
#
# [425 rows x 3 columns]

# %%
# To sort by index values use the companion method sort_index().
countries_reviewed.sort_index()
# Out:
#        country          province   len
# 0    Argentina  Mendoza Province  3264
# 1    Argentina             Other   536
# ..         ...               ...   ...
# 423    Uruguay          San Jose     3
# 424    Uruguay           Uruguay    24
#
# [425 rows x 3 columns]

# %%
countries_reviewed.sort_values(by=['country','len'])
# Out:
#        country          province   len
# 1    Argentina             Other   536
# 0    Argentina  Mendoza Province  3264
# ..         ...               ...   ...
# 424    Uruguay           Uruguay    24
# 419    Uruguay         Canelones    43
#
# [425 rows x 3 columns]

# %%
countries_reviewed.columns
# Out:
# Index(['country', 'province', 'len'], dtype='object')

# %% [markdown]
# ## LESSON 5: *Data Types and Missing Values*

# %%
#You can use the dtype property to grab the type of a specific column
reviews.price.dtype
# Out:
# dtype('float64')

# %%
# alternatively the 'dtype' property returns the dtype of every column  in the dataframe
reviews.dtypes
# Out:
# Unnamed: 0     int64
# country       object
#                ...
# variety       object
# winery        object
# Length: 14, dtype: object

# %%
reviews.points.astype('float64')
# Out:
# 0         87.0
# 1         87.0
#           ...
# 129969    90.0
# 129970    90.0
# Name: points, Length: 129971, dtype: float64

# %%
# A dataframe or series index has its own dtype
reviews.index.dtype
# Out:
# dtype('int64')

# %% [markdown]
# ### *Missing data*

# %%
#to select NaN entries you can use pd.isnull() (or its companion pd.notnull()).
reviews[pd.isnull(reviews.country)]
# Out:
#         Unnamed: 0 country                                        description  \
# 913            913     NaN  Amber in color, this wine has aromas of peach ...
# 3131          3131     NaN  Soft, fruity and juicy, this is a pleasant, si...
# ...            ...     ...                                                ...
# 129590      129590     NaN  A blend of 60% Syrah, 30% Cabernet Sauvignon a...
# 129900      129900     NaN  This wine offers a delightful bouquet of black...
#
#            designation  points  price province region_1 region_2  \
# 913     Asureti Valley      87   30.0      NaN      NaN      NaN
# 3131          Partager      83    NaN      NaN      NaN      NaN
# ...                ...     ...    ...      ...      ...      ...
# 129590            Shah      90   30.0      NaN      NaN      NaN
# 129900             NaN      91   32.0      NaN      NaN      NaN
#
#           taster_name taster_twitter_handle  \
# 913     Mike DeSimone        @worldwineguys
# ...

# %%
#. Pandas provides a really handy method for this problem: fillna()
reviews.region_2.fillna("Unknown")
# Out:
# 0         Unknown
# 1         Unknown
#            ...
# 129969    Unknown
# 129970    Unknown
# Name: region_2, Length: 129971, dtype: object

# %%
# changing values in a c column  in a dataset
reviews.taster_twitter_handle.replace("@kerinokeefe","@kerino")
# Out:
# 0            @kerino
# 1         @vossroger
#              ...
# 129969    @vossroger
# 129970    @vossroger
# Name: taster_twitter_handle, Length: 129971, dtype: object

# %% [markdown]
# ## LESSON 6: *Renaming and combining*

# %% [markdown]
# ### *Renaming* - The first function we'll introduce here is *rename()* , which lets you change index names and/or column names.

# %%
import pandas as pd
pd.set_option("display.max_rows",5)
reviews=pd.read_csv("winemag-data-130k-v2.csv",index_col=0)

# %%
reviews.rename(columns={'points':'score'})
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  score  price           province  \
# 0                        Vulkà Bianco     87    NaN  Sicily & Sardinia
# 1                            Avidagos     87   15.0              Douro
# ...                               ...    ...    ...                ...
# 129969                            NaN     90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline     90   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# 0          Etna      NaN  Kerin O’Keefe          @kerinokeefe
# ...

# %%
reviews.rename(index={0:'firstEntry',1:'secondEntry'})
# Out:
#               country                                        description  \
# firstEntry      Italy  Aromas include tropical fruit, broom, brimston...
# secondEntry  Portugal  This is ripe and fruity, a wine that is smooth...
# ...               ...                                                ...
# 129969         France  A dry style of Pinot Gris, this is crisp with ...
# 129970         France  Big, rich and off-dry, this is powered by inte...
#
#                                designation  points  price           province  \
# firstEntry                    Vulkà Bianco      87    NaN  Sicily & Sardinia
# secondEntry                       Avidagos      87   15.0              Douro
# ...                                    ...     ...    ...                ...
# 129969                                 NaN      90   32.0             Alsace
# 129970       Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
# ...

# %%
reviews.rename_axis('wines',axis='rows').rename_axis('fields',axis='columns')
# Out:
# fields   country                                        description  \
# wines
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
# fields                    designation  points  price           province  \
# wines
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
# fields region_1 region_2    taster_name taster_twitter_handle  \
# wines
# ...

# %% [markdown]
# #### *Combining*

# %% [markdown]
# #### If we want to study multiple countries simultaneously, we can use concat() to smush them together:

# %%
canadian_yt=pd.read_csv("CAvideos.csv")
british_yt=pd.read_csv("GBvideos.csv")
pd.concat([canadian_yt,british_yt])
# Out:
#           video_id trending_date  \
# 0      n1WpP7iowLc      17.14.11
# 1      0dBIkQ4Mz1M      17.14.11
# ...            ...           ...
# 38914  -DRsfNObKIQ      18.14.06
# 38915  4YFo4bdMO8Q      18.14.06
#
#                                                    title  \
# 0             Eminem - Walk On Water (Audio) ft. Beyoncé
# 1                          PLUSH - Bad Unboxing Fan Mail
# ...                                                  ...
# 38914  Eleni Foureira - Fuego - Cyprus - LIVE - First...
# 38915  KYLE - Ikuyo feat.  2 Chainz & Sophia Black [A...
#
#                  channel_title  category_id              publish_time  \
# 0                   EminemVEVO           10  2017-11-10T17:00:03.000Z
# 1                    iDubbbzTV           23  2017-11-13T17:00:00.000Z
# ...                        ...          ...                       ...
# 38914  Eurovision Song Contest           24  2018-05-08T20:32:32.000Z
# ...

# %% [markdown]
# #### The middlemost combiner in terms of complexity is join(). join() lets you combine different DataFrame objects which have an index in common. For example, to pull down videos that happened to be trending on the same day in both Canada and the UK, we could do the following:

# %%
left=canadian_yt.set_index(['title','trending_date'])
right=british_yt.set_index(['title','trending_date'])
left.join(right,lsuffix='_CAN',rsuffix='_UK')
# Out:
#                                                          video_id_CAN  \
# title                                      trending_date
# Eminem - Walk On Water (Audio) ft. Beyoncé 17.14.11       n1WpP7iowLc
# PLUSH - Bad Unboxing Fan Mail              17.14.11       0dBIkQ4Mz1M
# ...                                                               ...
# Trump Advisor Grovels To Trudeau           18.14.06       lbMKLzQ4cNQ
# 【完整版】遇到恐怖情人該怎麼辦？2018.06.13小明星大跟班           18.14.06       POTgw38-m58
#
#                                                          channel_title_CAN  \
# title                                      trending_date
# Eminem - Walk On Water (Audio) ft. Beyoncé 17.14.11             EminemVEVO
# PLUSH - Bad Unboxing Fan Mail              17.14.11              iDubbbzTV
# ...                                                                    ...
# Trump Advisor Grovels To Trudeau           18.14.06        The Young Turks
# ...
